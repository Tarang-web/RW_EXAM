# %% [markdown]
# **Q1**

# %%
print("Welcome to the Interactive Personal Data collector ")
print(end=" ")
Name =str(input("Please enter your name: "))
Age = int(input("Please enter your age: "))
Height = float(input("Please enter your height : "))
FNUM  = int(input("Please enter your favourite number: "))
print(end=" ")
print("Thank you! Here is the the information we collected: ")
print(end=" ")
print (f"Name:", {Name},"Type:", {type(Name)},"Memory Address:", {id(Name)})
print ("AGE:",Age,"Type:",type(Age),"Memory Address:",id(Age))
print ("HEIGHT:",Height,"Type:",type(Height),"Memory Address:",id(Height))
print ("Favourite Number:",FNUM,"Type:",type(FNUM),"Memory Address:",id(FNUM))
print (f"Your birth year is approximately: {2025-Age},base on your Age of :", Age )
print("Thank you for using the personal Data collector .Goodbye!")
# Out:
# Welcome to the Interactive Personal Data collector
#  Please enter your name: Alice
# Please enter your age: 25
# Please enter your height : 1.69
# Please enter your favourite number: 7
#  Thank you! Here is the the information we collected:
#  Name: {'Alice'} Type: {<class 'str'>} Memory Address: {140426506257712}
# AGE: 25 Type: <class 'int'> Memory Address: 10751624
# HEIGHT: 1.69 Type: <class 'float'> Memory Address: 140426548825040
# Favourite Number: 7 Type: <class 'int'> Memory Address: 10751048
# Your birth year is approximately: 2000,base on your Age of : 25
# Thank you for using the personal Data collector .Goodbye!
